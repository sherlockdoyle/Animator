# %%
import animator as am

scene = am.Scene()
with scene.quickdraw() as ctx:
    ctx.circle(scene.width / 2, scene.height / 2, 120)
    ctx.fillStyle = ctx.createLinearGradient(0, 0, 800, 800, [am.RED, am.BLUE], [0, 1])
    ctx.fill()
